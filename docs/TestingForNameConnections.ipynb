# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl

# %%
#get the dataset
data = pd.read_csv('~/Downloads/LondonStageCSV/DataViz Elizabeth Howe Appendix - Sheet1.csv')
data
# Out:
#              Actress    Year                            Play  \
# 0    Elizabeth Barry  1675.0                      Alcibiades
# 1    Elizabeth Barry  1676.0                       Abdelazar
# 2    Elizabeth Barry  1676.0            The Wrangling Lovers
# 3    Elizabeth Barry  1676.0                     Tom Essence
# 4    Elizabeth Barry  1676.0                    Madam Fickle
# ..               ...     ...                             ...
# 497        Nell Gwyn  1668.0             The Mulberry Garden
# 498        Nell Gwyn  1668.0               An Evening's Love
# 499        Nell Gwyn  1668.0       The Damoiselles a la Mode
# 500        Nell Gwyn  1669.0                  Tyrannick Love
# 501        Nell Gwyn  1670.0  The Conquest of Granada Part 2
#
#               Dramatist            Role        Type Generic markers
# 0          Thomas Otway        Draxilla        maid             NaN
# 1            Aphra Behn         Leonora  young girl             NaN
# 2    Edward Ravenscroft          Elvira  young girl             NaN
# 3        Thomas Rawlins       Theodocia  young girl             NaN
# 4         Thomas Durfey    Constantiana  young girl             NaN
# ..                  ...             ...         ...             ...
# 497      Charles Sedley          Olivia  young girl             NaN
# 498         John Dryden  Donna Jacintha  young girl             NaN
# 499    Richard Flecknoe         Lysette        maid             NaN
# 500         John Dryden         Valeria  young girl             NaN
# 501         John Dryden        Almahide  young girl             NaN
#
# [502 rows x 7 columns]

# %%
# get a lis of the unique plays
plays = data['Play'].unique()

# get a list of each unique actress
actresses = data['Actress'].unique()

# create a df that contins the number of connections between each two actresses
connections = pd.DataFrame(index=actresses, columns=actresses)

# for each play, get a list of the names of the actresses that has played in them 
for play in plays:
    actresses = data[data['Play'] == play]['Actress'].unique()
    # for each pair of actresses, add 1 to the number of connections between them
    for i in range(len(actresses)):
        for j in range(i + 1, len(actresses)):
            if pd.isna(connections.loc[actresses[i], actresses[j]]):
                connections.loc[actresses[i], actresses[j]] = 1
            else:
                connections.loc[actresses[i], actresses[j]] += 1
            if pd.isna(connections.loc[actresses[j], actresses[i]]):
                connections.loc[actresses[j], actresses[i]] = 1
            else:
                connections.loc[actresses[j], actresses[i]] += 1
#set the lower triangle of the connections matrix to 0
for i in range(len(connections)):
    for j in range(i):
        connections.iloc[i, j] = 0
connections
# Out:
#                      Elizabeth Barry Mary Betterton Jane Rogers  \
# Elizabeth Barry                  NaN             13           1
# Mary Betterton                     0            NaN           1
# Jane Rogers                        0              0         NaN
# Susannah Mountfort                 0              0           0
# Rebecca Marshall                   0              0           0
# Jane Long                          0              0           0
# Frances Maria Knight               0              0           0
# Mary Lee                           0              0           0
# Mary (‘Moll’) Davis                0              0           0
# Elizabeth Currer                   0              0           0
# Charlotte Butler                   0              0           0
# Anne Bracegirdle                   0              0           0
# Elizabeth Boutell                  0              0           0
# Nell Gwyn                          0              0           0
#
#                      Susannah Mountfort Rebecca Marshall Jane Long  \
# Elizabeth Barry                      10                1       NaN
# Mary Betterton                        2              NaN        11
# Jane Rogers                          15              NaN       NaN
# Susannah Mountfort                  NaN              NaN       NaN
# Rebecca Marshall                      0              NaN       NaN
# Jane Long                             0                0       NaN
# Frances Maria Knight                  0                0         0
# Mary Lee                              0                0         0
# Mary (‘Moll’) Davis                   0                0         0
# Elizabeth Currer                      0                0         0
# Charlotte Butler                      0                0         0
# Anne Bracegirdle                      0                0         0
# Elizabeth Boutell                     0                0         0
# Nell Gwyn                             0                0         0
#
#                      Frances Maria Knight Mary Lee Mary (‘Moll’) Davis  \
# Elizabeth Barry                         5       11                 NaN
# Mary Betterton                          2       19                   4
# Jane Rogers                            16        1                 NaN
# Susannah Mountfort                     24        3                 NaN
# Rebecca Marshall                      NaN      NaN                 NaN
# Jane Long                             NaN        3                   5
# Frances Maria Knight                  NaN        2                 NaN
# Mary Lee                                0      NaN                 NaN
# Mary (‘Moll’) Davis                     0        0                 NaN
# Elizabeth Currer                        0        0                   0
# Charlotte Butler                        0        0                   0
# Anne Bracegirdle                        0        0                   0
# Elizabeth Boutell                       0        0                   0
# Nell Gwyn                               0        0                   0
#
#                      Elizabeth Currer Charlotte Butler Anne Bracegirdle  \
# Elizabeth Barry                     7                5               27
# Mary Betterton                      6                1                3
# Jane Rogers                         1              NaN                4
# Susannah Mountfort                  4                6                9
# Rebecca Marshall                  NaN              NaN              NaN
# Jane Long                         NaN              NaN              NaN
# Frances Maria Knight                2                3                8
# Mary Lee                            7                2              NaN
# Mary (‘Moll’) Davis               NaN              NaN              NaN
# Elizabeth Currer                  NaN                3                1
# Charlotte Butler                    0              NaN                9
# Anne Bracegirdle                    0                0              NaN
# Elizabeth Boutell                   0                0                0
# Nell Gwyn                           0                0                0
#
#                      Elizabeth Boutell Nell Gwyn
# Elizabeth Barry                      3       NaN
# Mary Betterton                     NaN       NaN
# Jane Rogers                        NaN       NaN
# Susannah Mountfort                   2       NaN
# Rebecca Marshall                     8         5
# Jane Long                          NaN       NaN
# Frances Maria Knight                 1       NaN
# Mary Lee                           NaN       NaN
# Mary (‘Moll’) Davis                NaN       NaN
# Elizabeth Currer                   NaN       NaN
# Charlotte Butler                     3       NaN
# Anne Bracegirdle                     7       NaN
# Elizabeth Boutell                  NaN       NaN
# Nell Gwyn                            0       NaN

# %%
# Make a network graph of the connections
G = nx.Graph()
# add nodes
for actress in connections.index:
    G.add_node(actress)
# add edges
for i in range(len(connections.index)):
    for j in range(i + 1, len(connections.index)):
        if connections.iloc[i, j] > 0:
            G.add_edge(connections.index[i], connections.index[j], weight=connections.iloc[i, j])
# draw the graph
plt.figure(figsize=(15, 15))
pos = nx.spring_layout(G, k=0.5, iterations=500)
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color='lightblue', alpha=0.5)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif')
plt.axis('off')
plt.title('Network graph of actresses in London Stage')
plt.show()
